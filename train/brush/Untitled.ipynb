# %%
from PIL import Image

# %%
img = Image.open('brush_large_horizontal.png')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=LA size=394x394 at 0x7FEA540B4310>

# %%
stroke = Image.open('stroke.png')
